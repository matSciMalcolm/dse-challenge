# %%
import pandas as pd
import os
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.style.use('dark_background')

def plot_results(df, title):
    err = df[['accuracy_std','f1_std']]
    err.columns = ['accuracy','f1']
    ax = df[['accuracy','f1']].plot.barh(y=['accuracy','f1'], xerr=err, figsize=(4,6))
    ax.set_yticklabels(df['type'])
    ax.set_xlim((0,1))
    ax.grid(False)
    ax.legend(loc=(1.04, 0.85))
    ax.set_title(str(title))
    return ax

def plot_feature_results(df, mp_ax, title):
    df = df.sort_values('feature_set')
    err = df[['accuracy_std','f1_std']]
    err.columns = ['accuracy','f1']
    ax = df[['accuracy','f1']].plot.barh(y=['accuracy','f1'], xerr=err, ax=mp_ax)
    ax.set_yticklabels(df['feature_set'])
    ax.set_xlim((0,1))
    ax.set_title(str(title))
    ax.legend().set_visible(False)
    ax.grid(False)
    
    return ax

# %% [markdown]
# ## Experiment 1:
# Binary vs. Vector method

# %% [markdown]
# ### Baseline Classification Performance

# %%
bs_data_path = os.path.join('results','baseline','baseline.csv')
bs_df = pd.read_csv(bs_data_path).drop(['Unnamed: 0'], axis=1).sort_values('accuracy', ascending=False)

# %%
bs_df
# Out:
#                      type  data_size  accuracy  accuracy_std        f1  \
# 2  RandomForestClassifier        871  0.915012      0.022541  0.673610
# 3      LogisticRegression        871  0.874861      0.056559  0.636372
# 1                     SVC        871  0.833208      0.030400  0.000000
# 4         DummyClassifier        871  0.833208      0.030400  0.000000
# 0              GaussianNB        871  0.776015      0.083716  0.449831
#
#      f1_std    recall  recall_std  precision  precision_std
# 2  0.080569  0.532389    0.088506   0.931623       0.076861
# 3  0.113778  0.627497    0.108862   0.672184       0.158903
# 1  0.000000  0.000000    0.000000   0.000000       0.000000
# 4  0.000000  0.000000    0.000000   0.000000       0.000000
# 0  0.070163  0.539860    0.128882   0.411505       0.101495

# %%
acc_plot = plot_results(bs_df, 'Baseline Classification Performance')
max_base_acc = bs_df['accuracy'].max()
acc_plot.axvline(max_base_acc, linestyle='--')

# %% [markdown]
# ## Experiment 2: Effects of sampling
# Using a sample of 100 compare the model metrics before and after over sampling

# %%
e2_data_path = os.path.join('results','oversample','oversample_100.csv')
e2_df = pd.read_csv(e2_data_path).drop(['Unnamed: 0'], axis=1).sort_values('accuracy', ascending=False)

# %%
e2_df
# Out:
#                      type  data_size  accuracy  accuracy_std        f1  \
# 2  RandomForestClassifier        871  0.981534      0.010802  0.939223
# 1                     SVC        871  0.974759      0.009949  0.913910
# 3      LogisticRegression        871  0.917311      0.023338  0.730950
# 4         DummyClassifier        871  0.833208      0.030400  0.000000
# 0              GaussianNB        871  0.798203      0.071666  0.471515
#
#      f1_std    recall  recall_std  precision  precision_std
# 2  0.037622  0.893581    0.058670   0.991667       0.026352
# 1  0.043988  0.844098    0.072228   1.000000       0.000000
# 3  0.091252  0.698945    0.143247   0.799146       0.117500
# 4  0.000000  0.000000    0.000000   0.000000       0.000000
# 0  0.093334  0.525574    0.104147   0.489534       0.225050

# %%
sampling_plot = plot_results(e2_df, 'Effects of sampling')
sampling_plot.axvline(max_base_acc, linestyle='--')

# %% [markdown]
# ## Experiment 3: Impact of Feature Engineering

# %%
e3_data_path = os.path.join('results','features','features.csv')
e3_df = pd.read_csv(e3_data_path).sort_values('accuracy', ascending=False).rename({'Unnamed: 9': 'feature_set'}, axis=1)

# %%
groups = e3_df.groupby('type')

# %%
import numpy as np
fig,axs = plt.subplots(4,1, sharex=True, sharey=True, figsize=(8,11))
fig.suptitle('Impact of Feature Engineering')

for model, ax in zip(groups.groups, axs):
    data = groups.get_group(model)
    plot_feature_results(data, ax, model)
    ax.axvline(max_base_acc, linestyle='--')
    
plt.legend(loc = 'lower center', bbox_to_anchor = (0.7,0.5,1,1),
            bbox_transform = plt.gcf().transFigure )

# %%
feature_plot = plot_results(e3_df, 'Impact of Feature Engineering')
feature_plot.set_yticklabels(e3_df['feature_set'])
# group by
# Out:
# <function matplotlib.pyplot.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)>

# %% [markdown]
# ## Experiment 4: Dataset Size
