# %%
# Imports
import pandas as pd
import os
import typing
from functools import partial
from pprint import pprint
from pypif import pif
from pypif.obj import *

# %%
# Load Data
# Filter to comp
# Parse Vector
# Upload to citrination

# %%
# make pifs
def df_to_pif(row: pd.Series, pifs: list) -> pd.Series:
    sys = ChemicalSystem()
    sys.names = row['formula']
    sys.chemical_formula = row['formula']
    sys.properties = Property(name='stable', scalars=row['stable'])
    '''
    for name, val in row.iteritems():
        sys.properties.append(Property(name=name, scalars=Scalar(value=val)))
    '''
    pifs.append(sys)
    return row

# %%
load_path = os.path.join('data','processed_data.csv')
save_path = os.path.join('data','pifs_data.json')

# %%
df = pd.read_csv(load_path)

# %%
df.drop_duplicates()
# Out:
#           formula formulaA formulaB  stable
# 0              Ne       Ne       He       1
# 1              Cs       Cs       He       1
# 2               K        K       He       1
# 3              Ba       Ba       He       1
# 4              Sr       Sr       He       1
# 5              Br       Br       He       1
# 6              Na       Na       He       1
# 7              La       La       He       1
# 8              Pr       Pr       He       1
# 9              Ce       Ce       He       1
# 10             Te       Te       He       1
# 11             Pm       Pm       He       1
# 12             Gd       Gd       He       1
# 13              Y        Y       He       1
# 14             Tb       Tb       He       1
# 15             Dy       Dy       He       1
# 16             Lu       Lu       He       1
# 17             Tl       Tl       He       1
# 18             Sn       Sn       He       1
# 19             Sc       Sc       He       1
# 20             Mg       Mg       He       1
# 21             Li       Li       He       1
# 22              U        U       He       1
# 23             Np       Np       He       1
# 24             Ta       Ta       He       1
# 25             Nb       Nb       He       1
# 26             Mo       Mo       He       1
# 27             Pt       Pt       He       1
# 28             Re       Re       He       1
# 29             Pd       Pd       He       1
# ...           ...      ...      ...     ...
# 25772  Ca0.0 B1.0       Ca        B       1
# 25773   I0.0 B1.0        I        B       1
# 25774  Br0.0 B1.0       Br        B       1
# 25775  Bi0.0 B1.0       Bi        B       1
# 25776  Pr0.0 B1.0       Pr        B       1
# 25777  Nd0.0 B1.0       Nd        B       1
# 25778  Sm0.0 B1.0       Sm        B       1
# 25779  Th0.0 B1.0       Th        B       1
# 25780  Dy0.0 B1.0       Dy        B       1
# 25781  Ho0.0 B1.0       Ho        B       1
# 25782  Lu0.0 B1.0       Lu        B       1
# 25783  Tl0.0 B1.0       Tl        B       1
# 25784  Sc0.0 B1.0       Sc        B       1
# 25785  Ge0.0 B1.0       Ge        B       1
# 25786  Cd0.0 B1.0       Cd        B       1
# 25787  Li0.0 B1.0       Li        B       1
# 25788   U0.0 B1.0        U        B       1
# 25789  Ga0.0 B1.0       Ga        B       1
# 25790  Np0.0 B1.0       Np        B       1
# 25791  Nb0.0 B1.0       Nb        B       1
# 25792  Ag0.0 B1.0       Ag        B       1
# 25793  Al0.0 B1.0       Al        B       1
# 25794  Mo0.0 B1.0       Mo        B       1
# 25795  Pd0.0 B1.0       Pd        B       1
# 25796  Tc0.0 B1.0       Tc        B       1
# 25797  Cr0.0 B1.0       Cr        B       1
# 25798  Cu0.0 B1.0       Cu        B       1
# 25799  Fe0.0 B1.0       Fe        B       1
# 25800  Ni0.0 B1.0       Ni        B       1
# 25801   C0.0 B1.0        C        B       1
#
# [25802 rows x 4 columns]

# %%
pifs = []

# %%
dtp = partial(df_to_pif, pifs=pifs)

# %%
pif_tdf = df.apply(dtp, axis=1)

# %%
with open(save_path,'w') as f:
    pif.dump(pifs, f, indent=2)
